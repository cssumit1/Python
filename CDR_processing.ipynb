# %%
import pandas as pd

# %%
pd.read_csv('./cdr_py/cdr_Air-Arabia-Cluster_01_202208170618_2705164')
# Out:
#   cdrRecordType globalCallID_callManagerId globalCallID_callId  \
# 0       INTEGER                    INTEGER             INTEGER
# 1             1                          1             9191338
# 2             1                          1             9191345
# 3             1                          1             9191346
#
#   origLegCallIdentifier dateTimeOrigination origNodeId  origSpan  origIpAddr  \
# 0               INTEGER             INTEGER    INTEGER   INTEGER     INTEGER
# 1              33460190          1660717043          1  33460190  -267399670
# 2              33460202          1660717080          1         0           0
# 3              33460205          1660717081          1         0           0
#
#   callingPartyNumber callingPartyUnicodeLoginUserID  ...  \
# 0        VARCHAR(50)                   VARCHAR(128)  ...
# 1                NaN                            NaN  ...
# 2                NaN                            NaN  ...
# ...

# %%
pd.read_csv('./cdr_py/cdr_Air-Arabia-Cluster_01_202208170618_2705164')
# Out:
#   cdrRecordType globalCallID_callManagerId globalCallID_callId  \
# 0       INTEGER                    INTEGER             INTEGER
# 1             1                          1             9191338
# 2             1                          1             9191345
# 3             1                          1             9191346
#
#   origLegCallIdentifier dateTimeOrigination origNodeId  origSpan  origIpAddr  \
# 0               INTEGER             INTEGER    INTEGER   INTEGER     INTEGER
# 1              33460190          1660717043          1  33460190  -267399670
# 2              33460202          1660717080          1         0           0
# 3              33460205          1660717081          1         0           0
#
#   callingPartyNumber callingPartyUnicodeLoginUserID  ...  \
# 0        VARCHAR(50)                   VARCHAR(128)  ...
# 1                NaN                            NaN  ...
# 2                NaN                            NaN  ...
# ...

# %%
# import modules
import os
import pandas as pd
 
# assign path
path, dirs, files = next(os.walk("./cdr_py/"))
file_count = len(files)
# create empty list
dataframes_list = []
 
# append datasets to the list
for i in range(file_count):
    temp_df = pd.read_csv("./cdr_py/"+files[i])
    dataframes_list.append(temp_df)
     
# display datasets
for dataset in dataframes_list:
    display(dataset)
# Out:
#   cdrRecordType globalCallID_callManagerId globalCallID_callId  \
# 0       INTEGER                    INTEGER             INTEGER
# 1             1                          1             9191335
# 2             1                          1             9191324
#
#   origLegCallIdentifier dateTimeOrigination origNodeId  origSpan  origIpAddr  \
# 0               INTEGER             INTEGER    INTEGER   INTEGER     INTEGER
# 1              33460188          1660716994          1  33460188  1930872842
# 2              33460174          1660716858          1  33460174  1930872842
#
#   callingPartyNumber callingPartyUnicodeLoginUserID  ...  \
# 0        VARCHAR(50)                   VARCHAR(128)  ...
# 1        10509909349                            NaN  ...
# 2        10545191544                            NaN  ...
#
#   finalMobileCalledPartyNumber origMobileDeviceName destMobileDeviceName  \
# 0                  VARCHAR(50)         VARCHAR(129)         VARCHAR(129)
# ...
